# %%
import pandas as pd

# %%
df = pd.read_csv('tmdb.movies.csv', index_col="Unnamed: 0")
df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# ...

# %%
df.isna().sum()
# Out:
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    25497
# True      1020
# dtype: int64

# %%
df[df.duplicated(keep = False)].sort_values(by = 'title')
# Out:
#                 genre_ids      id original_language  \
# 9191                 [99]   95383                en
# 6315                 [99]   95383                en
# 20070     [99, 36, 10770]  430364                en
# 26340     [99, 36, 10770]  430364                en
# 18016         [18, 10749]  416691                en
# ...                   ...     ...               ...
# 21273                [18]  326382                es
# 15061         [10751, 16]   94196                fr
# 5888          [10751, 16]   94196                fr
# 25188  [10752, 10751, 36]  472553                en
# 21676  [10752, 10751, 36]  472553                en
#
#                                        original_title  popularity  \
# 9191                                       $ellebrity       1.420
# 6315                                       $ellebrity       1.420
# 20070  '85: The Greatest Team in Pro Football History       0.600
# 26340  '85: The Greatest Team in Pro Football History       0.600
# ...

# %%
df.drop_duplicates(subset = None, keep = 'first', inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    25497
# dtype: int64

# %%
df.drop(['original_language', 'original_title'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (25497, 7)

# %% [markdown]
# Changing the release_date column to Date

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df.dtypes
# Out:
# genre_ids               object
# id                       int64
# popularity             float64
# release_date    datetime64[ns]
# title                   object
# vote_average           float64
# vote_count               int64
# dtype: object

# %%
df
# Out:
#                  genre_ids      id  popularity release_date  \
# 0          [12, 14, 10751]   12444      33.533   2010-11-19
# 1      [14, 12, 16, 10751]   10191      28.734   2010-03-26
# 2            [12, 28, 878]   10138      28.515   2010-05-07
# 3          [16, 35, 10751]     862      28.005   1995-11-22
# 4            [28, 878, 12]   27205      27.920   2010-07-16
# ...                    ...     ...         ...          ...
# 26512             [27, 18]  488143       0.600   2018-10-13
# 26513             [18, 53]  485975       0.600   2018-05-01
# 26514         [14, 28, 12]  381231       0.600   2018-10-01
# 26515      [10751, 12, 28]  366854       0.600   2018-06-22
# 26516             [53, 27]  309885       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# ...
